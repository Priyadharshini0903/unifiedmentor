# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel("C:/Users/PRAVEEN/Desktop/unified mentor/Bird Strikes data (1).xlsx")

# %%
data
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680            NaN                              NaN          NaN
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
# ...

# %%
data.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                             859         Engine Shut Down 2000-11-23
# 1                             424                      NaN 2001-07-25
# ...

# %%
data.tail()
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680            NaN                              NaN          NaN
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 25553              EMB-120                       1
# 25554                A-321                       1
# 25555               EC-135                     NaN
# 25556            B-757-200                       1
# 25557            B-737-400                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 25553                               1                      NaN 2011-12-30
# ...

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680            NaN                              NaN          NaN
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
# ...

# %%
data.isnull()
# Out:
#        Record ID  Aircraft: Type  Airport: Name  Altitude bin  \
# 0          False           False          False         False
# 1          False           False          False         False
# 2          False           False          False         False
# 3          False           False          False         False
# 4          False           False          False         False
# ...          ...             ...            ...           ...
# 25553      False           False          False         False
# 25554      False           False          False         False
# 25555      False            True           True          True
# 25556      False           False          False         False
# 25557      False           False          False         False
#
#        Aircraft: Make/Model  Wildlife: Number struck  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# ...

# %%
data.isnull().sum()
# Out:
# Record ID                                      0
# Aircraft: Type                               129
# Airport: Name                                129
# Altitude bin                                 129
# Aircraft: Make/Model                           0
# Wildlife: Number struck                      129
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23480
# FlightDate                                   129
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                 267
# Aircraft: Airline/Operator                   129
# Origin State                                 449
# When: Phase of flight                        129
# Conditions: Precipitation                  23543
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# Remarks                                     4771
# Wildlife: Size                               129
# ...

# %%
data.isnull().sum().sum()
# Out:
# 53929

# %%
df = data

# %%
#filling null values with the previous values

df=df.fillna(method='pad')
df
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680       Airplane                     ORLANDO INTL    < 1000 ft
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
# ...

# %%
df.isnull().sum()
# Out:
# Record ID                                   0
# Aircraft: Type                              0
# Airport: Name                               0
# Altitude bin                                0
# Aircraft: Make/Model                        0
# Wildlife: Number struck                     0
# Wildlife: Number Struck Actual              0
# Effect: Impact to flight                    0
# FlightDate                                  0
# Effect: Indicated Damage                    0
# Aircraft: Number of engines?                0
# Aircraft: Airline/Operator                  0
# Origin State                                0
# When: Phase of flight                       0
# Conditions: Precipitation                  13
# Remains of wildlife collected?              0
# Remains of wildlife sent to Smithsonian     0
# Remarks                                     0
# Wildlife: Size                              0
# Conditions: Sky                             0
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Record ID                                  0
# Aircraft: Type                             0
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Remarks                                    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# ...

# %%
df.describe().T
# Out:
#                                   count                           mean  \
# Record ID                       25545.0                  253937.651282
# Wildlife: Number Struck Actual  25545.0                       2.520532
# FlightDate                        25545  2007-01-26 16:46:16.840869120
# Cost: Total $                   25545.0                    5452.920611
# Feet above ground               25545.0                     799.513016
# Number of people injured        25545.0                       0.001057
#
#                                                 min                  25%  \
# Record ID                                    1195.0             225811.0
# Wildlife: Number Struck Actual                  1.0                  1.0
# FlightDate                      2000-01-02 00:00:00  2004-06-20 00:00:00
# Cost: Total $                                   0.0                  0.0
# Feet above ground                               0.0                  0.0
# ...

# %%
data.describe(include='all').T
# Out:
#                                            count unique  \
# Record ID                                25558.0    NaN
# Aircraft: Type                             25429      1
# Airport: Name                              25429   1109
# Altitude bin                               25429      2
# Aircraft: Make/Model                       25558    351
# Wildlife: Number struck                  25429.0    4.0
# Wildlife: Number Struck Actual           25558.0    NaN
# Effect: Impact to flight                    2078      4
# FlightDate                                 25429    NaN
# Effect: Indicated Damage                   25558      2
# Aircraft: Number of engines?             25291.0    5.0
# Aircraft: Airline/Operator                 25429    292
# Origin State                               25109     60
# When: Phase of flight                      25429      7
# Conditions: Precipitation                   2015      7
# Remains of wildlife collected?             25558      2
# ...

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Effect: Impact to flight', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remarks', 'Wildlife: Size', 'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Is Aircraft Large?'],
#       dtype='object')
# Numerical Variables:
# ['Record ID', 'Wildlife: Number Struck Actual', 'Cost: Total $', 'Feet above ground', 'Number of people injured']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Record ID
# Skew : -0.52
# Wildlife: Number Struck Actual
# Skew : 43.8
# Cost: Total $
# Skew : 57.88
# Feet above ground
# Skew : 3.49
# Number of people injured
# Skew : 79.62

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Aircraft: Type', data = data, color = 'blue', 
              order = data['Aircraft: Type'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Airport: Name', data = data, color = 'blue', 
              order = data['Airport: Name'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Altitude bin', data = data, color = 'blue', 
              order = data['Altitude bin'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Aircraft: Make/Model', data = data, color = 'blue', 
              order = data['Aircraft: Make/Model'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Wildlife: Number struck', data = data, color = 'blue', 
              order = data['Wildlife: Number struck'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Effect: Impact to flight', data = data, color = 'blue', 
              order = data['Effect: Impact to flight'].head(20).value_counts().index);


sns.countplot(ax = axes[0, 0], x = 'Effect: Indicated Damage', data = data, color = 'blue', 
              order = data['Effect: Indicated Damage'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Aircraft: Number of engines?', data = data, color = 'blue', 
              order = data['Aircraft: Number of engines?'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Aircraft: Airline/Operator', data = data, color = 'blue', 
              order = data['Aircraft: Airline/Operator'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Origin State', data = data, color = 'blue', 
              order = data['Origin State'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Wildlife: Number struck', data = data, color = 'blue', 
              order = data['Wildlife: Number struck'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'When: Phase of flight', data = data, color = 'blue', 
              order = data['When: Phase of flight'].head(20).value_counts().index);



sns.countplot(ax = axes[0, 0], x = 'Conditions: Precipitation', data = data, color = 'blue', 
              order = data['Conditions: Precipitation'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Wildlife: Size', data = data, color = 'blue', 
              order = data['Wildlife: Size'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Is Aircraft Large?', data = data, color = 'blue', 
              order = data['Is Aircraft Large?'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Conditions: Sky', data = data, color = 'blue', 
              order = data['Conditions: Sky'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Wildlife: Species', data = data, color = 'blue', 
              order = data['Wildlife: Species'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Pilot warned of birds or wildlife?', data = data, color = 'blue', 
              order = data['Pilot warned of birds or wildlife?'].head(20).value_counts().index);

axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %%
# Function for log transformation of the column
def log_transform(data,col):
    for colname in col:
        if (data[colname] == 1.0).all():
            data[colname + '_log'] = np.log(data[colname]+1)
        else:
            data[colname + '_log'] = np.log(data[colname])
    data.info()

# %%
log_transform(data,['Wildlife: Number Struck Actual', 'Cost: Total $'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  int64
#  1   Aircraft: Type                           25429 non-null  object
#  2   Airport: Name                            25429 non-null  object
#  3   Altitude bin                             25429 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25429 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 2078 non-null   object
#  8   FlightDate                               25429 non-null  datetime64[ns]
#  9   Effect: Indicated Damage                 25558 non-null  object
# ...

# %%
sns.distplot(data["Wildlife: Number Struck Actual_log"], axlabel="Wildlife: Number Struck Actual_log");

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=data.drop(['Wildlife: Number Struck Actual',' Cost: Total $'],axis=1))
plt.show()
